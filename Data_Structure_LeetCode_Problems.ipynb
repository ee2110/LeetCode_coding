# %% [markdown]
# # **Max Consecutive Ones**
#
# Given a binary array nums, return the maximum number of consecutive 1's in the array.

# %%
# Example

'''
Input: nums = [1,1,0,1,1,1]
Output: 3
Explanation: The first two digits or the last three digits are consecutive 1s. 
The maximum number of consecutive 1s is 3.

Constraints:
1 <= nums.length <= 105
nums[i] is either 0 or 1.
'''

# %%
'''
strategy
1. iterate all element in array
2. check if the current num is 1, if yes, count plus 1.
3. check if num is 1 or 0
4. If is 1, count + 1; if is 0, count = 0
5. check the total consecutive count one, if is greater than previous, replace the max count value 
'''

def findMaxConsecutiveOnes(nums):
    max_cons = 0
    one_count = 0

    for i in nums:
      if i == 1:
        one_count+=1

      if i == 0:
        one_count = 0

      if max_cons < one_count:
        max_cons = one_count

    return(max_cons)

# %%
nums = [1,1,0,1,1,1,1,1,0,0,1,1,1,1,0,0,1,1,1]

# %%
print('The maximum number of consecutive 1s is: ', findMaxConsecutiveOnes(nums))
# Out:
# The maximum number of consecutive 1s is:  5

# %% [markdown]
# Submission Results:
#
#
# *   Status: Accepted
# *   42 / 42 test cases passed.
# *   Runtime: 292 ms (Your runtime beats 72.22 % of python submissions.)
# *   Memory Usage: 13.7 MB
# *   Your memory usage beats 67.47 % of python submissions.

# %% [markdown]
# # **Find Numbers with Even Number of Digits**
#
# Given an array nums of integers, return how many of them contain an even number of digits.

# %%
# Example

''' 
Input: nums = [12,345,2,6,7896]
Output: 2
Explanation: 
12 contains 2 digits (even number of digits). 
345 contains 3 digits (odd number of digits). 
2 contains 1 digit (odd number of digits). 
6 contains 1 digit (odd number of digits). 
7896 contains 4 digits (even number of digits). 
Therefore only 12 and 7896 contain an even number of digits.
'''

# %%
nums = [12,345,2,6,7896,256,128,1024]

# %%
def findNumbers(nums):
  even_digit = []

  for i in nums:
    num_len = 0
    digit_count = 0

    for n in str(i):
      digit_count+=1
    
    if digit_count % 2==0:
      even_digit.append(i)
    
  return even_digit

# %%
print('The number with even digit numbers is :', len(findNumbers(nums)))
print('The number are ', even_digit)
# Out:
# The number with even digit numbers is : 3
# The number are  [12, 7896, 1024]

# %% [markdown]
# Submission Results:
#
#
# *   Status: Accepted
# *   104 / 104 test cases passed.
# *   Runtime: 40 ms (Your runtime beats 54.93 % of python submissions.)
# *   Memory Usage: 13.5 MB
# *   Your memory usage beats 55.30 % of python submissions.

# %% [markdown]
# # **Squares of a Sorted Array**
#
# Given an integer array nums sorted in non-decreasing order, return an array of the squares of each number sorted in non-decreasing order.

# %%
# Example

'''
Input: nums = [-4,-1,0,3,10]
Output: [0,1,9,16,100]
Explanation: After squaring, the array becomes [16,1,0,9,100].
After sorting, it becomes [0,1,9,16,100].
'''

# %%
nums = [-7,-3,2,3,11]

# %%
def sortedSquares_1(nums):

  squared_num = []
  for i in nums:
    squared_num.append(i*i)

  sorted_num = []
  copy_squared_num = squared_num

  while squared_num:
      min_num = copy_squared_num[0]
      
      for x in copy_squared_num: 
          if x < min_num:
            min_num = x

      sorted_num.append(min_num)
      copy_squared_num.remove(min_num)

  return sorted_num

# %%
sortedSquares_1(nums)
# Out:
# [4, 9, 9, 49, 121]

# %% [markdown]
# Submission 1 Results:
#
#
# *   Status: Time Limit Exceeded
# *   131 / 137 test cases passed.
# *   Runtime: NA
# *   Memory Usage: NA
#
# ***Although answer correct, but time limit exceeded, need correction***

# %%
'''
strategy
1. Instead of using old style algorithm, use built-in function, sorted
'''

def sortedSquares_2(nums):

  squared_num = []
  for i in nums:
    squared_num.append(i*i)

  return sorted(squared_num)

# %%
sortedSquares_2(nums)
# Out:
# [4, 9, 9, 49, 121]

# %% [markdown]
# Submission 2 Results:
#
#
# *   Status: Accepted
# *   137 / 137 test cases passed.
# *   Runtime: 336 ms (Your runtime beats 6.87 % of python submissions.)
# *   Memory Usage: 15.6 MB
# *   Your memory usage beats 52.65 % of python submissions.
#
# ***Although answer correct, and within time limit, but runtime still have room of improvement***

# %%
'''
strategy
1. Use same function as in Solution 2, but simplify the line
'''

def sortedSquares_3(nums):
  
  return sorted([i*i for i in nums])

# %%
sortedSquares_3(nums)
# Out:
# [4, 9, 9, 49, 121]

# %% [markdown]
# Submission 3 Results:
#
#
# *   Status: Accepted
# *   137 / 137 test cases passed.
# *   Runtime: 188 ms (Your runtime beats 66.65 % of python submissions.)
# *   Memory Usage: 15.8 MB
# *   Your memory usage beats 52.65 % of python submissions.
#
# ***The runtime is successfully halved!***
